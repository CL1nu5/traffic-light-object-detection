# %% [markdown]
# # 3. Evaluation and inference
# Evaluate tiles and stitched full frames, then save full-resolution three-class predictions.

# %%
from pathlib import Path
import sys

CONFIG = next(path for path in (Path('.config/config.toml'), Path('../.config/config.toml')) if path.exists())
ROOT = CONFIG.resolve().parent.parent
sys.path.insert(0, str(ROOT / 'src'))

from traffic_light_prediction.evaluation import evaluate_and_infer

# %%
result = evaluate_and_infer(CONFIG)
result
