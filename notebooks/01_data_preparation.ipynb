# %% [markdown]
# # 1. Data preparation
# Download LISA, convert its full traffic-light boxes to YOLO, and create video-grouped train/validation/test splits.

# %%
from pathlib import Path
import sys

CONFIG = next(path for path in (Path('.config/config.toml'), Path('../.config/config.toml')) if path.exists())
ROOT = CONFIG.resolve().parent.parent
sys.path.insert(0, str(ROOT / 'src'))

from traffic_light_prediction.data import prepare_dataset

# %%
summary = prepare_dataset(CONFIG)
summary['splits']
